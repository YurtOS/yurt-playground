# %% [markdown]
# # Yurt playground
#
# This notebook runs on a real CPython 3.14 `ipykernel` inside a Yurt sandbox in
# this browser tab. Nothing leaves the page.

# %%
import sys
sys.version

# %%
import numpy as np
np.arange(6).reshape(2, 3) @ np.ones((3, 1))
